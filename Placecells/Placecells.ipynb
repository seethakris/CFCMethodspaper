# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.2)
import pandas as pd
import warnings
import sys
import scipy.io

warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
DataDetailsFolder = '/Users/seethakrishnan/Library/CloudStorage/Box-Box/CFC/ImagingData/Scripts/'
sys.path.append(DataDetailsFolder)
import AnimalDetails
from placecellremapping import PlottingFunctions as gd

# %%
TaskDict = {'Task1': 'Control VR',
             'Task2': 'CFC VR',
             'Task3': 'During CFC',
             'Task4': 'Control VR Recall',
             'Task5': 'CFC VR Recall'}

# %% [markdown]
# ## CFC3

# %%
FolderName = '/Users/seethakrishnan/Library/CloudStorage/Box-Box/CFC/ImagingData/CFC3/'
CFC3 = AnimalDetails.CFCAnimals('CFC3')

# %%
pc = gd(animalinfo=CFC3,
  taskdict=TaskDict,
  FolderName=FolderName)
# Out:
# 569
# Task5
# Task5 : Place cells: 282 PlaceFields: 335
# Task1
# Task1 : Place cells: 94 PlaceFields: 100
# Task3
# Task3 : Place cells: 106 PlaceFields: 118
# Task2
# Task2 : Place cells: 126 PlaceFields: 129
# Task4
# Task4 : Place cells: 196 PlaceFields: 231
# Task5
# Task1
# Task3
# Task2
# Task4

# %%
pcdict, sortedpcs = pc.get_and_sort_placeactivity()
pc.plot_placecells_with_track_pertask(pcdict, sortedpcs)
pc.save_pcs(pcdict, 'pcs_pertask')

# %%
pcdict = pc.calculate_remapping_within_task('Task1')
pcdict = pc.calculate_remapping_within_task('Task2')

# %%
pcdict, sortedpcs = pc.calculate_remapping_with_task('Task1')
pc.plot_placecells_with_track_pertask(pcdict, sortedpcs)

# %%
pcdict, sortedpcs = pc.calculate_remapping_with_task('Task2')
pc.plot_placecells_with_track_pertask(pcdict, sortedpcs)

# %% [markdown]
# ## CFC26

# %%
FolderName = '/Users/seethakrishnan/Library/CloudStorage/Box-Box/CFC/ImagingData/CFC26/'
CFC26 = AnimalDetails.CFCAnimals('CFC26')

# %%
pc = gd(animalinfo=CFC26,
  taskdict=TaskDict,
  FolderName=FolderName)
# Out:
# 917
# Task2
# Task2 : Place cells: 216 PlaceFields: 242
# Task4
# Task4 : Place cells: 209 PlaceFields: 251
# Task1
# Task1 : Place cells: 187 PlaceFields: 232
# Task5
# Task5 : Place cells: 385 PlaceFields: 520
# Task3
# Task3 : Place cells: 87 PlaceFields: 112
# Task2
# Task4
# Task1
# Task5
# Task3

# %%
pcdict, sortedpcs = pc.get_and_sort_placeactivity()
pc.plot_placecells_with_track_pertask(pcdict, sortedpcs)
pc.save_pcs(pcdict, 'pcs_pertask')

# %%
pcdict = pc.calculate_remapping_within_task('Task1')
pcdict = pc.calculate_remapping_within_task('Task2')

# %%
pcdict, sortedpcs = pc.calculate_remapping_with_task('Task1')
pc.plot_placecells_with_track_pertask(pcdict, sortedpcs)

# %%
pcdict, sortedpcs = pc.calculate_remapping_with_task('Task2')
pc.plot_placecells_with_track_pertask(pcdict, sortedpcs)

# %% [markdown]
# ## DG10

# %%
FolderName = '/Users/seethakrishnan/Library/CloudStorage/Box-Box/CFC/ImagingData/DG10/'
DG10 = AnimalDetails.CFCAnimals('DG10')

# %%
pc = gd(animalinfo=DG10,
  taskdict=TaskDict,
  FolderName=FolderName)
# Out:
# 1031
# Task2
# Task2 : Place cells: 370 PlaceFields: 451
# Task3
# Task3 : Place cells: 260 PlaceFields: 306
# Task5
# Task5 : Place cells: 356 PlaceFields: 459
# Task4
# Task4 : Place cells: 400 PlaceFields: 518
# Task1
# Task1 : Place cells: 364 PlaceFields: 412
# Task2
# Task3
# Task5
# Task4
# Task1

# %%
pcdict, sortedpcs = pc.get_and_sort_placeactivity()
pc.plot_placecells_with_track_pertask(pcdict, sortedpcs)
pc.save_pcs(pcdict, 'pcs_pertask')

# %%
pcdict = pc.calculate_remapping_within_task('Task1')
pcdict = pc.calculate_remapping_within_task('Task2')

# %%
pcdict, sortedpcs = pc.calculate_remapping_with_task('Task1')
pc.plot_placecells_with_track_pertask(pcdict, sortedpcs)

# %%
pcdict, sortedpcs = pc.calculate_remapping_with_task('Task2')
pc.plot_placecells_with_track_pertask(pcdict, sortedpcs)

# %% [markdown]
# ## NR21

# %%
FolderName = '/Users/seethakrishnan/Library/CloudStorage/Box-Box/CFC/ImagingData/NR22/'
NR22 = AnimalDetails.CFCAnimals('NR22')

# %%
pc = gd(animalinfo=NR22,
  taskdict=TaskDict,
  FolderName=FolderName)
# Out:
# 532
# Task1
# Task1 : Place cells: 133 PlaceFields: 157
# Task5
# Task5 : Place cells: 364 PlaceFields: 594
# Task4
# Task4 : Place cells: 104 PlaceFields: 113
# Task3
# Task3 : Place cells: 165 PlaceFields: 185
# Task2
# Task2 : Place cells: 162 PlaceFields: 183
# Task1
# Task5
# Task4
# Task3
# Task2

# %%
pcdict, sortedpcs = pc.get_and_sort_placeactivity()
pc.plot_placecells_with_track_pertask(pcdict, sortedpcs)
pc.save_pcs(pcdict, 'pcs_pertask')

# %%
pcdict = pc.calculate_remapping_within_task('Task1')
pcdict = pc.calculate_remapping_within_task('Task2')

# %%
pcdict, sortedpcs = pc.calculate_remapping_with_task('Task1')
pc.plot_placecells_with_track_pertask(pcdict, sortedpcs)

# %%
pcdict, sortedpcs = pc.calculate_remapping_with_task('Task2')
pc.plot_placecells_with_track_pertask(pcdict, sortedpcs)
